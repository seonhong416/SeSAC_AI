# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint

from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('./data/house_train.csv')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageCond        81
# GarageType        81
# GarageFinish      81
# GarageQual        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# Id                 0
# dtype: int64

# %%
# 카테고리형(범주형) 데이터 처리 > 0,1 로 변환(one hot encoding)

df = pd.get_dummies(df)

df.head(10)
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
# 5   6          50         85.0    14115            5            5       1993
# 6   7          20         75.0    10084            8            5       2004
# 7   8          60          NaN    10382            7            6       1973
# 8   9          50         51.0     6120            7            5       1931
# 9  10         190         50.0     7420            5            6       1939
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLw  SaleType_New  \
# ...

# %%
# 결측치 처리(평균값으로 대체)

df.mean()
# Out:
# Id                         730.500000
# MSSubClass                  56.897260
# LotFrontage                 70.049958
# LotArea                  10516.828082
# OverallQual                  6.099315
#                              ...
# SaleCondition_AdjLand        0.002740
# SaleCondition_Alloca         0.008219
# SaleCondition_Family         0.013699
# SaleCondition_Normal         0.820548
# SaleCondition_Partial        0.085616
# Length: 290, dtype: float64

# %%
df = df.fillna(df.mean())

# %%
# EDA
# 속성별 관련도 추출

df.corr()
# Out:
#                              Id  MSSubClass  LotFrontage   LotArea  \
# Id                     1.000000    0.011156    -0.009601 -0.033226
# MSSubClass             0.011156    1.000000    -0.357056 -0.139781
# LotFrontage           -0.009601   -0.357056     1.000000  0.306795
# LotArea               -0.033226   -0.139781     0.306795  1.000000
# OverallQual           -0.028365    0.032628     0.234196  0.105806
# ...                         ...         ...          ...       ...
# SaleCondition_AdjLand -0.034852    0.016241    -0.037020 -0.013208
# SaleCondition_Alloca  -0.009018    0.030002    -0.018090  0.008966
# SaleCondition_Family   0.004865    0.000983     0.015818 -0.010781
# SaleCondition_Normal   0.015881    0.024359    -0.072074  0.005711
# SaleCondition_Partial -0.020738   -0.051068     0.124842  0.022635
#
#                        OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# Id                       -0.028365     0.012609  -0.012713     -0.021998
# ...

# %%
df_corr = df.corr()

# 집 값과 관련 큰 순서대로 저장하기

df_corr.sort_values('SalePrice', ascending = False)
# Out:
#                         Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# SalePrice        -0.021917   -0.084284     0.334901  0.263843     0.790982
# OverallQual      -0.028365    0.032628     0.234196  0.105806     1.000000
# GrLivArea         0.008273    0.074853     0.368392  0.263116     0.593007
# GarageCars        0.016570   -0.040110     0.269729  0.154871     0.600671
# GarageArea        0.017634   -0.098672     0.323663  0.180403     0.562022
# ...                    ...         ...          ...       ...          ...
# MasVnrType_None   0.024897   -0.023867    -0.121677 -0.032418    -0.397955
# GarageFinish_Unf -0.007513   -0.008807    -0.188336 -0.068099    -0.422479
# BsmtQual_TA       0.033795   -0.138741    -0.066531 -0.044874    -0.497957
# KitchenQual_TA   -0.014973   -0.010836    -0.136764 -0.031154    -0.553891
# ExterQual_TA     -0.011072   -0.041021    -0.141738 -0.027890    -0.646247
#
# ...

# %%
df_corr_sort = df_corr.sort_values('SalePrice', ascending = False)

# 집 값과 관련도가 가장 큰 10개의 속성만 추출, 출력

df_corr_sort['SalePrice'].head(10)
# Out:
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# BsmtQual_Ex     0.553105
# TotRmsAbvGrd    0.533723
# Name: SalePrice, dtype: float64

# %%
df_corr_sort['SalePrice'].head(10).index
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
#        'TotalBsmtSF', '1stFlrSF', 'FullBath', 'BsmtQual_Ex', 'TotRmsAbvGrd'],
#       dtype='object')

# %%
# 집 값과 관련도가 가장 높은 순으로 추출된 상관된 그래프 그리기

cols = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
       'TotalBsmtSF', '1stFlrSF', 'FullBath', 'BsmtQual_Ex', 'TotRmsAbvGrd']

# %%
sns.pairplot(df[cols])
plt.show()

# %%
# 주택가격 예측 모델

# 속성 정보

x = df[cols].iloc[:, 1:]
y = df['SalePrice'].values

# %%
# 학습셋 테스트 셋 구분

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
# 모델 구조 설정
model = Sequential()
model.add(Dense(10, input_dim = x_train.shape[1], activation='relu'))
model.add(Dense(30, activation='relu'))
model.add(Dense(40, activation='relu'))
model.add(Dense(1))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 10)                100
#
#  dense_5 (Dense)             (None, 30)                330
#
#  dense_6 (Dense)             (None, 40)                1240
#
#  dense_7 (Dense)             (None, 1)                 41
#
# ...
# Total params: 1,711
# Trainable params: 1,711
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델 컴파일
model.compile(loss = 'mean_squared_error', optimizer='adam')

# 조기종료
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=20)

# 모델 이름 정하기
modelpath = './model/house/house.hdf5'

# 최적화 모델 업데이트 >> 저장
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=0, save_best_only=True)

# 전체 20의 검증셋(val_set) 설정
history = model.fit(x_train, y_train, validation_split=0.25, epochs = 2000, batch_size = 32,
                    callbacks=[early_stopping_callback, checkpointer])
# Out:
# Epoch 1/2000
# 28/28 [==============================] - 0s 5ms/step - loss: 38904369152.0000 - val_loss: 36274147328.0000
# Epoch 2/2000
# 28/28 [==============================] - 0s 2ms/step - loss: 38329212928.0000 - val_loss: 35453435904.0000
# Epoch 3/2000
# 28/28 [==============================] - 0s 2ms/step - loss: 36941545472.0000 - val_loss: 33418211328.0000
# Epoch 4/2000
# 28/28 [==============================] - 0s 2ms/step - loss: 33671024640.0000 - val_loss: 28895463424.0000
# Epoch 5/2000
# 28/28 [==============================] - 0s 2ms/step - loss: 27094413312.0000 - val_loss: 20601536512.0000
# Epoch 6/2000
# 28/28 [==============================] - 0s 2ms/step - loss: 16772553728.0000 - val_loss: 9775028224.0000
# Epoch 7/2000
# 28/28 [==============================] - 0s 3ms/step - loss: 6692554240.0000 - val_loss: 2800282112.0000
# Epoch 8/2000
# 28/28 [==============================] - 0s 2ms/step - loss: 2575635712.0000 - val_loss: 1758301312.0000
# ...

# %%
# 예측값과 실제값, 실행번호가 들어갈 빈 리스트 생성
real_price = []
pred_price = []
x_num = []

# 임의로 40개 뽑아서 실제값, 예측값 출력
n_iter = 0
y_pred = model.predict(x_test).flatten()

for i in range(40) :
    real = y_test[i]
    prediction = y_pred[i]
    print(f'실제가격 : {round(real,2)}, 예상가격:{round(prediction, 2)}')
    real_price.append(real)
    pred_price.append(prediction)
    n_iter = n_iter + 1
    x_num.append(n_iter)
# Out:
# 10/10 [==============================] - 0s 794us/step
# 실제가격 : 274725, 예상가격:205586.6875
# 실제가격 : 155000, 예상가격:165517.359375
# 실제가격 : 290000, 예상가격:288500.1875
# 실제가격 : 113000, 예상가격:135329.671875
# 실제가격 : 253293, 예상가격:349901.375
# 실제가격 : 182900, 예상가격:198680.046875
# 실제가격 : 625000, 예상가격:392531.75
# 실제가격 : 114504, 예상가격:136882.96875
# 실제가격 : 318000, 예상가격:274346.0
# 실제가격 : 127000, 예상가격:154652.875
# 실제가격 : 195000, 예상가격:201286.90625
# 실제가격 : 123500, 예상가격:141634.296875
# 실제가격 : 138000, 예상가격:156860.34375
# 실제가격 : 106500, 예상가격:65192.71875
# 실제가격 : 212000, 예상가격:191221.046875
# 실제가격 : 104000, 예상가격:169850.375
# 실제가격 : 215000, 예상가격:201974.421875
# 실제가격 : 84500, 예상가격:122148.0078125
# 실제가격 : 98300, 예상가격:84005.8515625
# 실제가격 : 149000, 예상가격:166455.0625
# 실제가격 : 125000, 예상가격:129663.359375
# 실제가격 : 235000, 예상가격:231377.234375
# 실제가격 : 204900, 예상가격:224722.21875
# 실제가격 : 147000, 예상가격:277746.5
# 실제가격 : 118000, 예상가격:74966.296875
# 실제가격 : 259000, 예상가격:223904.453125
# 실제가격 : 314813, 예상가격:269482.375
# ...

# %%
df = pd.DataFrame(np.array([real_price, pred_price]).T, index = x_num, columns = ['real', 'pred'])
df
# Out:
#         real           pred
# 1   274725.0  205586.671875
# 2   155000.0  165517.359375
# 3   290000.0  288500.187500
# 4   113000.0  135329.671875
# 5   253293.0  349901.375000
# 6   182900.0  198680.046875
# 7   625000.0  392531.750000
# 8   114504.0  136882.968750
# 9   318000.0  274346.000000
# 10  127000.0  154652.875000
# 11  195000.0  201286.906250
# 12  123500.0  141634.296875
# 13  138000.0  156860.343750
# 14  106500.0   65192.722656
# 15  212000.0  191221.031250
# 16  104000.0  169850.375000
# 17  215000.0  201974.421875
# 18   84500.0  122148.007812
# 19   98300.0   84005.851562
# 20  149000.0  166455.062500
# 21  125000.0  129663.359375
# 22  235000.0  231377.234375
# 23  204900.0  224722.218750
# 24  147000.0  277746.500000
# 25  118000.0   74966.304688
# 26  259000.0  223904.468750
# 27  314813.0  269482.375000
# 28  138800.0  145800.421875
# 29  135000.0  139440.078125
# 30  149900.0  207090.031250
# 31  192000.0  189613.640625
# 32  129500.0  191161.718750
# ...

# %%
round(df,2)
# Out:
#         real       pred
# 1   274725.0  205586.67
# 2   155000.0  165517.36
# 3   290000.0  288500.19
# 4   113000.0  135329.67
# 5   253293.0  349901.38
# 6   182900.0  198680.05
# 7   625000.0  392531.75
# 8   114504.0  136882.97
# 9   318000.0  274346.00
# 10  127000.0  154652.88
# 11  195000.0  201286.91
# 12  123500.0  141634.30
# 13  138000.0  156860.34
# 14  106500.0   65192.72
# 15  212000.0  191221.03
# 16  104000.0  169850.38
# 17  215000.0  201974.42
# 18   84500.0  122148.01
# 19   98300.0   84005.85
# 20  149000.0  166455.06
# 21  125000.0  129663.36
# 22  235000.0  231377.23
# 23  204900.0  224722.22
# 24  147000.0  277746.50
# 25  118000.0   74966.30
# 26  259000.0  223904.47
# 27  314813.0  269482.38
# 28  138800.0  145800.42
# 29  135000.0  139440.08
# 30  149900.0  207090.03
# 31  192000.0  189613.64
# 32  129500.0  191161.72
# 33  170000.0  232511.73
# 34  176500.0  193583.28
# 35  133500.0  124721.34
# 36  187750.0  193403.75
# 37  243000.0  223568.02
# ...

# %%
# 그래프 그리기

plt.plot(df.index, pred_price, label = 'predicted_price')
plt.plot(df.index, real_price, label = 'real_price')
plt.legend()
plt.show()

# %%
df['diff'] = df['real'] - df['pred']

df
# Out:
#         real           pred           diff
# 1   274725.0  205586.671875   69138.328125
# 2   155000.0  165517.359375  -10517.359375
# 3   290000.0  288500.187500    1499.812500
# 4   113000.0  135329.671875  -22329.671875
# 5   253293.0  349901.375000  -96608.375000
# 6   182900.0  198680.046875  -15780.046875
# 7   625000.0  392531.750000  232468.250000
# 8   114504.0  136882.968750  -22378.968750
# 9   318000.0  274346.000000   43654.000000
# 10  127000.0  154652.875000  -27652.875000
# 11  195000.0  201286.906250   -6286.906250
# 12  123500.0  141634.296875  -18134.296875
# 13  138000.0  156860.343750  -18860.343750
# 14  106500.0   65192.722656   41307.277344
# 15  212000.0  191221.031250   20778.968750
# 16  104000.0  169850.375000  -65850.375000
# 17  215000.0  201974.421875   13025.578125
# 18   84500.0  122148.007812  -37648.007812
# 19   98300.0   84005.851562   14294.148438
# 20  149000.0  166455.062500  -17455.062500
# 21  125000.0  129663.359375   -4663.359375
# ...

# %%
plt.plot(df.index, df['diff'], label = 'diff')
plt.show()
